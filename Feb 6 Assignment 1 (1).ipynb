# %% [markdown]
# Q2. Write a python program for encrypting a message sent to you by your friend. The logic of encryption
# should be such that, for a the output should be z. For b, the output should be y. For c, the output should
# be x respectively. Also, the whitespace should be replaced with a dollar sign. Keep the punctuation
# marks unchanged.
# Input Sentence: I want to become a Data Scientist.
# Encrypt the above input sentence using the program you just created.
# Note: Convert the given input

# %%
l="i want to become a data scientist."
l1=l.lower()
l2=[]
for i in l1:
    if i=="a":
        l2.append("z")
    elif  i=="b":
        l2.append("y")
    elif  i=="c":
        l2.append("x")
    elif  i=="d":
        l2.append("w")
    elif  i=="d":
        l2.append("v")
    elif  i=="e":
        l2.append("v")
    elif  i=="f":
        l2.append("u")
    elif  i=="g":
        l2.append("t")
    elif  i=="h":
        l2.append("s")
    elif  i=="i":
        l2.append("r")
    elif  i=="j":
        l2.append("q")
    elif  i=="k":
        l2.append("p")
    elif  i=="l":
        l2.append("o")
    elif  i=="m":
        l2.append("n")
    elif  i=="n":
        l2.append("m")
    elif  i=="o":
        l2.append("l")
    elif  i=="p":
        l2.append("k")
    elif  i=="q":
        l2.append("j")
    elif  i=="r":
        l2.append("i")
    elif  i=="s":
        l2.append("h")
    elif  i=="t":
        l2.append("g")
    elif  i=="u":
        l2.append("f")
    elif  i=="v":
        l2.append("e")
    elif  i=="w":
        l2.append("d")
    elif  i=="x":
        l2.append("c")
    elif  i=="y":
        l2.append("b")
    elif  i=="z":
        l2.append("a")
    elif  i==" ":
        l2.append("$")
    else:
        l2.append(".")
output="".join(l2)
print(output)
# Out:
# r$dzmg$gl$yvxlnv$z$wzgz$hxrvmgrhg.

# %% [markdown]
# ********************************

# %% [markdown]
# Q1. Create a function which will take a list as an argument and return the product of all the numbers
# after creating a flat list.
# Use the below-given list as an argument for your function.
# list1 = [1,2,3,4, [44,55,66, True], False, (34,56,78,89,34), {1,2,3,3,2,1}, {1:34, "key2": [55, 67, 78, 89], 4: (45,
# 22, 61, 34)}, [56, 'data science'], 'Machine Learning']
# Note: you must extract numeric keys and values of the dictionary also.

# %%
list1 = [1,2,3,4, [44,55,66, True], False, (34,56,78,89,34), {1,2,3,3,2,1}, {1:34, "key2": [55, 67, 78, 89], 4: (45,
22, 61, 34)}, [56, 'data science'], 'Machine Learning']

# %%
l1=[]  #output with int and bool

for i in list1:
    if type(i)==int:
        l1.append(i) ###output
for i in list1:
    if type(i)== bool:
        l1.append(i) ###output
for i in list1:
    if type(i)==str:
        l1.append(i)  ## output with str
        
l2=[]  #output with list's int bool and str 

for i in list1:
    if type(i)==list:
        for j in i:
            if type(j)==int:
                l2.append(j) ###output with int
            elif type(j)== bool:
                l2.append(j)  ###output with bool
            elif type(j)== str:
                l2.append(j) ##output with str
            
                
                
l3=[]  #output with tuple
for i in list1:
    if type(i)==tuple:
        for j in i:
            if type(j)==int:
                l3.append(j)  ### final output for the tuple
                
                
l4=[]  #output with set
for i in list1:
    if type(i)==set:
        for j in i:
            l4.append(j)  #final output for the set
        
        
dic1=[]

for i in list1:
    if type(i)==dict:
        dic1.append(i)
        
        
dic2=dic1[0]
l6=[]
for i in l5:
    l6.append(i)
    
l5=dic2.keys()

l6=[]  #output of dic keys
for i in l5:
    l6.append(i)  #final key output
    
l7=dic2.values()

l8=[]
for i in l7:
    l8.append(i)  #valueoutput
    
l9=[]   #final output of dic value
for i in l8:
    if type(i)==int:
        l9.append(i)
        
    elif type(i)==list:
        for j in i:
            l9.append(j)
            
    elif type(i)==tuple:
        for j in i:
            l9.append(j)
            
l10=[]  #flat list of all the characters including the str
l10.extend(l1)
l10.extend(l2)
l10.extend(l3)
l10.extend(l4)
l10.extend(l6)
l10.extend(l9)


l11=[]  #flat list of all the integers only
for i in l10:
    if type(i)==int:
        l11.append(i)
        
from functools import reduce
print("Multiplication result  of all the integers", reduce(lambda x,y: x*y,l11))
print("\n")
print("List of all the integers","=",l11)
print("\n")
print("Flat lists of all the characters including bool, int, str in list tuple and dict","=",l10)
# Out:
# Multiplication result  of all the integers 4134711838987085478833841242112000
#
#
# List of all the integers = [1, 2, 3, 4, 44, 55, 66, 56, 34, 56, 78, 89, 34, 1, 2, 3, 1, 4, 34, 55, 67, 78, 89, 45, 22, 61, 34]
#
#
# Flat lists of all the characters including bool, int, str in list tuple and dict = [1, 2, 3, 4, False, 'Machine Learning', 44, 55, 66, True, 56, 'data science', 34, 56, 78, 89, 34, 1, 2, 3, 1, 'key2', 4, 34, 55, 67, 78, 89, 45, 22, 61, 34]
